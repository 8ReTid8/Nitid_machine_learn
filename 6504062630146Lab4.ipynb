# %% [markdown]
# ## Auto-MPG
#
# ![](https://factsanddetails.com/media/2/20111201-Molycorp%20REs-hev.png)
#
# ###The data is technical spec of cars, aiming to predict city fuel consumption
# ### (mile-per-gallon: MPG).
#
# The features consist of
# *   cylinders
# *   displacement
# *   horsepower
# *   weight
# *   acceleration
# *   model year
# *   original
# *   car name
#
# The output
# mpg mile-per-gallon
#
# [source] https://gist.githubusercontent.com/omarish/5687264/raw/7e5c814ce6ef33e25d5259c1fe79463c190800d9/mpg.csv

# %% [markdown]
# ## ข้อ 1

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("https://gist.githubusercontent.com/omarish/5687264/raw/7e5c814ce6ef33e25d5259c1fe79463c190800d9/mpg.csv")
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# ## ข้อ 2

# %%
print(df.isin(['?']).sum())
df.dtypes
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model_year        int64
# origin            int64
# name             object
# dtype: object

# %% [markdown]
# ## ข้อ 3

# %%
df = df.drop(['name'],axis=1)
df['horsepower'].replace(('?', np.nan),inplace = True)
df['horsepower'] = df['horsepower'].astype(int)
df['horsepower'].fillna(df['horsepower'].mean(), inplace = True)
print(df.isin(['?']).sum())
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64
# <ipython-input-88-dbbd796f84ad>:2: FutureWarning: Series.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df['horsepower'].replace(('?', np.nan),inplace = True)

# %% [markdown]
# ## ข้อ 4

# %%
from sklearn.model_selection import train_test_split
X = df.drop(["mpg"],axis=1)
Y = df['mpg']
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
print(X_train.shape, X_test.shape)
# Out:
# (318, 7) (80, 7)

# %% [markdown]
# ## ข้อ 5

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
# print('pred :',y_pred)
print('w1 : ',model.coef_)
print('w0 : ',model.intercept_)
# Out:
# w1 :  [-0.36373971  0.02333084 -0.02231756 -0.00682224  0.11347385  0.80881327
#   1.40758102]
# w0 :  -21.847074328975232

# %% [markdown]
# ## ข้อ 6

# %%
print(mean_squared_error(y_test, y_pred))
# Out:
# 8.441960312391355

# %% [markdown]
# ## ข้อ 7
# ### อับโหลดข้อมูลจ 'transactions.csv' จาก google classroom

# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv("transactions.csv")
df1.dropna(axis=0,inplace = True)
# df1['Date'] = pd.to_datetime(df1['Date'])
df1['Date'] = pd.to_datetime(df1['Date'], format='%d/%m/%Y')
df1.set_index('Date',inplace = True)
df1
# Out:
#               P1    P2    P3
# Date
# 2022-01-01   6.0  15.0  31.0
# 2022-01-02  19.0   0.0  30.0
# 2022-01-03  14.0  20.0   6.0
# 2022-01-04  10.0  21.0  17.0
# 2022-01-05   7.0  20.0  33.0
# ...          ...   ...   ...
# 2023-12-27  16.0  21.0  35.0
# 2023-12-28   3.0   4.0  17.0
# 2023-12-29   0.0  12.0  31.0
# 2023-12-30   7.0  28.0  19.0
# 2023-12-31  16.0  17.0  29.0
#
# [730 rows x 3 columns]

# %% [markdown]
# ## ข้อ 8

# %%
print(df1['P1'].mean())
print(df1['P3'].mean())
# Out:
# 9.23013698630137
# 27.44931506849315

# %% [markdown]
# ## ข้อ 9

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
dfp1 = df1.drop(['P3','P2'],axis=1)
dfp1['P1_t+1'] = df1['P1'].shift(-1)
dfp1.fillna(dfp1.mean(),inplace = True)
print(dfp1)
X = dfp1.drop(["P1_t+1"],axis=1)
Y = dfp1['P1_t+1']
X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=700,shuffle=False)
print(X_train.shape, X_test.shape)
model1 = LinearRegression()
model1.fit(X_train, y_train)
y_pred = model1.predict(X_test)
print('pred :',y_pred)
print('w1 : ',model1.coef_)
print('w0 : ',model1.intercept_)
# Out:
#               P1     P1_t+1
# Date
# 2022-01-01   6.0  19.000000
# 2022-01-02  19.0  14.000000
# 2022-01-03  14.0  10.000000
# 2022-01-04  10.0   7.000000
# 2022-01-05   7.0   6.000000
# ...          ...        ...
# 2023-12-27  16.0   3.000000
# 2023-12-28   3.0   0.000000
# 2023-12-29   0.0   7.000000
# 2023-12-30   7.0  16.000000
# 2023-12-31  16.0   9.234568
#
# [730 rows x 2 columns]
# (700, 1) (30, 1)
# pred : [9.122702   8.94235833 8.89727241 8.89727241 9.57356117 9.61864709
#  9.61864709 8.98744425 9.57356117 9.21287383 9.03253016 8.80710058
#  8.98744425 9.16778792 9.30304567 9.3932175  8.8521865  9.52847525
#  9.3932175  9.34813158 9.16778792 9.43830342 9.43830342 9.25795975
#  9.48338933 9.52847525 8.94235833 8.80710058 9.122702   9.52847525]
# w1 :  [0.04508592]
# w0 :  8.80710058021273

# %% [markdown]
# ## ข้อ 10

# %%
print("mean absolute error (MAE): ",mean_absolute_error(y_test, y_pred))
# Out:
# mean absolute error (MAE):  5.109253227990938

# %% [markdown]
# ## ข้อ 11

# %%
# weekly_data = df1.resample('W').agg({'P2': 'sum'}).reset_index()
# weekly_data['P2(w-1)'] = weekly_data['P2'].shift(1)  # Previous week
# weekly_data['P2(w+1)'] = weekly_data['P2'].shift(-1)  # Next week
# weekly_data.dropna(inplace=True)
# weekly_data.drop(weekly_data.index[0], inplace=True)
# weekly_data['Date'] = pd.to_datetime(weekly_data['Date'], format='%d/%m/%Y')
# weekly_data.set_index('Date',inplace = True)
# dfp2 = weekly_data

dfp2 = df1.drop(['P1','P3'],axis=1)
dfp2['P2(w-1)'] = df1['P2'].shift(7)
dfp2['P2(w+1)'] = df1['P2'].shift(-7)
dfp2.dropna(inplace=True)
X = dfp2.drop(["P2(w+1)"],axis=1)
Y = dfp2['P2(w+1)']
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=28,shuffle=False)
print(X_train.shape, X_test.shape)
model2 = LinearRegression()
model2.fit(X_train, y_train)
y_pred = model2.predict(X_test)
print('pred :',y_pred)
print('w1 : ',model2.coef_)
print('w0 : ',model2.intercept_)
dfp2
# Out:
# (688, 2) (28, 2)
# pred : [15.3594293  16.99657036 15.73209086 16.59416907 15.69243789 15.73209086
#  15.49858068 16.63639185 16.41022511 16.97417407 16.89964176 16.68375424
#  16.76306018 17.1232387  16.909555   15.41670493 15.38439539 16.39774206
#  16.90735118 15.75705696 16.01773706 16.20645466 17.32957895 17.3394922
#  15.1707117  17.87847506 17.67727442 16.39039862]
# w1 :  [-0.04222278  0.07453231]
# w0 :  15.970374668694575
#               P2  P2(w-1)  P2(w+1)
# Date
# 2022-01-08   6.0     15.0     24.0
# 2022-01-09  10.0      0.0     19.0
# 2022-01-10  10.0     20.0     18.0
# 2022-01-11   3.0     21.0     10.0
# 2022-01-12  14.0     20.0     10.0
# ...          ...      ...      ...
# 2023-12-20  17.0     28.0     21.0
# 2023-12-21  26.0      4.0      4.0
# 2023-12-22   6.0     29.0     12.0
# 2023-12-23   9.0     28.0     28.0
# 2023-12-24  13.0     13.0     17.0
#
# [716 rows x 3 columns]

# %% [markdown]
# ## ข้อ 12

# %%
print("mean absolute error (MAE): ",mean_absolute_error(y_test, y_pred))
# Out:
# mean absolute error (MAE):  8.210735939331844

# %% [markdown]
# ## ข้อ 13
